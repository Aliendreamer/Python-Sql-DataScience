# %%
import pandas as pd
import nose.tools
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
accidents_data=pd.read_csv("data/accidents.csv")

# %%
print("accidents_data")
# Out:
# accidents_data

# %%
accidents_data
# Out:
#   Miles from Home  % of Accidents
# 0     less than 1              23
# 1          1 to 5              29
# 2         6 to 10              17
# 3        11 to 15               8
# 4        16 to 20               6
# 5         over 20              17

# %%
titanset_data= pd.read_csv('data/titanset.txt')

# %%
titanset_data
# Out:
#       pclass  survived                                               name  \
# 0        1.0       1.0                      Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                     Allison, Master. Hudson Trevor
# 2        1.0       0.0                       Allison, Miss. Helen Loraine
# 3        1.0       0.0               Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5        1.0       1.0                                Anderson, Mr. Harry
# 6        1.0       1.0                  Andrews, Miss. Kornelia Theodosia
# 7        1.0       0.0                             Andrews, Mr. Thomas Jr
# 8        1.0       1.0      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9        1.0       0.0                            Artagaveytia, Mr. Ramon
# 10       1.0       0.0                             Astor, Col. John Jacob
# 11       1.0       1.0  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
titanset_data.isnull().sum()
# Out:
# pclass          1
# survived        1
# name            1
# sex             1
# age           264
# sibsp           1
# parch           1
# ticket          1
# fare            2
# cabin        1015
# embarked        3
# boat          824
# body         1189
# home.dest     565
# dtype: int64

# %%
irisdata =pd.read_csv("data/irisdataset.txt")

# %%
count=len(irisdata.index)
print(count)
# Out:
# 150

# %%
irisdata
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# 5             5.4          3.9           1.7          0.4     Iris-setosa
# 6             4.6          3.4           1.4          0.3     Iris-setosa
# 7             5.0          3.4           1.5          0.2     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# 9             4.9          3.1           1.5          0.1     Iris-setosa
# 10            5.4          3.7           1.5          0.2     Iris-setosa
# 11            4.8          3.4           1.6          0.2     Iris-setosa
# ...

# %%
irisdata =irisdata[(irisdata['sepal_length'] >=4.5) & (irisdata['sepal_length'] <= 10)]

# %%
irisdata
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# 5             5.4          3.9           1.7          0.4     Iris-setosa
# 6             4.6          3.4           1.4          0.3     Iris-setosa
# 7             5.0          3.4           1.5          0.2     Iris-setosa
# 9             4.9          3.1           1.5          0.1     Iris-setosa
# 10            5.4          3.7           1.5          0.2     Iris-setosa
# 11            4.8          3.4           1.6          0.2     Iris-setosa
# 12            4.8          3.0           1.4          0.1     Iris-setosa
# ...

# %%
columns_of_interest = ['petal_length']

irisdata.mean(axis=0)[ columns_of_interest ]
# Out:
# petal_length    3.826712
# dtype: float64

# %%
red_wine=pd.read_csv("data/winequality-red.csv",delimiter =';')

# %%
white_wine=pd.read_csv("data/winequality-white.csv",delimiter =';')

# %%
red_wine
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# ...

# %%
white_wine
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.0             0.270         0.36           20.70      0.045
# 1               6.3             0.300         0.34            1.60      0.049
# 2               8.1             0.280         0.40            6.90      0.050
# 3               7.2             0.230         0.32            8.50      0.058
# 4               7.2             0.230         0.32            8.50      0.058
# 5               8.1             0.280         0.40            6.90      0.050
# 6               6.2             0.320         0.16            7.00      0.045
# 7               7.0             0.270         0.36           20.70      0.045
# 8               6.3             0.300         0.34            1.60      0.049
# 9               8.1             0.220         0.43            1.50      0.044
# 10              8.1             0.270         0.41            1.45      0.033
# ...

# %%
columns_of_interest = ['quality']
red_wine.mean(axis=0)[ columns_of_interest ]
# Out:
# quality    5.636023
# dtype: float64

# %%
columns_of_interest = ['quality']
white_wine.mean(axis=0)[ columns_of_interest ]
# Out:
# quality    5.877909
# dtype: float64

# %%
columns_of_interest = ['alcohol']
red_wine.mean(axis=0)[ columns_of_interest ]
# Out:
# alcohol    10.422983
# dtype: float64

# %%
columns_of_interest = ['alcohol']
white_wine.mean(axis=0)[ columns_of_interest ]
# Out:
# alcohol    10.514267
# dtype: float64

# %%
red_wine['alcohol'].corr(red_wine['quality'])
# Out:
# 0.47616632400113595

# %%
white_wine['alcohol'].corr(white_wine['quality'])
# Out:
# 0.4355747154613735

# %%
mpg_data = pd.read_fwf("http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data",header = None, 
names=["mpg","cylinders","displacement","horsepower","weight","acceleration","model_year","origin","car_name"])

# %%
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999

# %%
mpg_data

# %%
mpg_data.info()

# %%
mpg_data['horsepower'] = mpg_data['horsepower'].apply(pd.to_numeric, errors='coerce')

# %%
mpg_data.info()

# %%
def get_unique_model_years(dataframe):
    """
    Returns the unique values of the "model_year" column
    of the dataframe
    """
    model_years = dataframe.model_year.unique() 
    # YOUR CODE HERE
    #raise NotImplementedError()
    return model_years

# %%
model_years = get_unique_model_years(mpg_data)
print(model_years)
# Out:
# [70 71 72 73 74 75 76 77 78 79 80 81 82]

# %%
#mpg_data['model_year']='19' + mpg_data['model_year'].astype(str)
mpg_data['model_year'] = pd.to_datetime('19' + mpg_data['model_year'].astype(str)).dt.year

# %%
model_years = get_unique_model_years(mpg_data)
print(model_years)
# Out:
# [1970 1971 1972 1973 1974 1975 1976 1977 1978 1979 1980 1981 1982]

# %%
income_data =pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data',header=None,na_values=["?"],
         names=["age","working_class","fmlgtw","education","education_num","marital_status","occupation","relationship" ,"race","sex","capital_gain","capital_loss","hours_per_week","native_country","total_income"])

# %%
nuclear.groupby('ne').count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-605cb6ab2473> in <module>()
# ----> 1 nuclear.groupby('ne').count()
#
# NameError: name 'nuclear' is not defined

# %%
income_data =pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data',header=None,na_values=["?"],
    names=["age","working_class","fmlgtw","education","education_num","marital_status","occupation","relationship"
                              ,"race","sex","capital_gain","capital_loss","hours_per_week","native_country","total_income",sep=", "])

# %%
income_data

# %%
nuclear=pd.read_csv('https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/csv/boot/nuclear.csv')

# %%
nuclear

# %%
 nuclear['date']=pd.to_datetime(nuclear['date'], unit='d', origin=pd.Timestamp('1990-01-01'))
 #nuclear['date'] = pd.to_datetime(nuclear["1976"], unit='d')

# %%
nuclear.groupby('ne').count()
# Out:
#     Unnamed: 0  cost  date  t1  t2  cap  pr  ct  bw  cum.n  pt
# ne
# 0           24    24    24  24  24   24  24  24  24     24  24
# 1            8     8     8   8   8    8   8   8   8      8   8

# %%
income_data =pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data',header=None,na_values=["?"],
    names=["age","working_class","fmlgtw","education","education_num","marital_status","occupation","relationship"
                              ,"race","sex","capital_gain","capital_loss","hours_per_week","native_country","total_income"],
               sep=", ")

# %%
df

# %%
list=income_data.groupby(['total_income']).size()

#income_data['total_income'] =income_data['total_income'].apply(>50k)

#income_data['total_income'] =income_data['total_income'].apply(lambda x: x > 0)

# %%
high_paid=df.groupby(['total_income']).size().idxmin()

# %%
list
# Out:
# total_income
#  <=50K    24720
#  >50K      7841
# dtype: int64

# %%
df.groupby(['total_income']).size()[1]
# Out:
# 7841

# %%
values =df['capital_gain']
plt.hist(values)
plt.show()

# %%
high=df.groupby(['total_income']).size()['<=50K']

# %%
def get_num_people_with_higher_gain(dataframe, threshold_gain):
    # YOUR CODE HERE
    
        return  num_people

# %%
high
# Out:
# 24720

# %%
 get_num_people_with_higher_gain(income_data,60000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-8e8dfce6cc41> in <module>()
# ----> 1 get_num_people_with_higher_gain(income_data,60000)
#
# <ipython-input-53-2d82f65d49d4> in get_num_people_with_higher_gain(dataframe, threshold_gain)
#       2     # YOUR CODE HERE
#       3
# ----> 4         return  num_people
#
# NameError: name 'num_people' is not defined

# %%
#num_people = income_data["capital_gain"].clip_lower(60000).count
#df[df['capital_gain'] >60000]

# %%
#num_people = df['capital_gain']>=60000.count
#df1 = df.query("capital_gain < 60000")
df[ df.capital_gain >60000]
#highpayed= len(df.index)
# Out:
#        age     working_class  fmlgtw     education  education_num  \
# 1246    54      Self-emp-inc  166459   Prof-school             15
# 1368    52           Private  152234       HS-grad              9
# 1482    53      Self-emp-inc  263925       HS-grad              9
# 1528    52           Private  118025     Bachelors             13
# 1616    46           Private  370119   Prof-school             15
# 1682    43           Private  176270     Bachelors             13
# 1765    49           Private  159816     Bachelors             13
# 1771    50           Private  171338  Some-college             10
# 1826    22  Self-emp-not-inc  202920       HS-grad              9
# 2103    43      Self-emp-inc  172826  Some-college             10
# 2319    65      Self-emp-inc  139272     Bachelors             13
# 2361    26           Private  256000   Prof-school             15
# 2707    52  Self-emp-not-inc   64045   Prof-school             15
# ...

# %%
nuclear=pd.read_csv('https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/csv/boot/nuclear.csv')

# %%
nuclear

# %%
nuclear.groupby('ne').count()

# %%
highpayed=len(df[ df.capital_gain >25000
                ])
print(highpayed)

# %%
highpayed
# Out:
# 215

# %%
df.groupby('marital_status').count()
# Out:
#                          age  working_class  fmlgtw  education  education_num  \
# marital_status
# Divorced                4443           4259    4443       4443           4443
# Married-AF-spouse         23             21      23         23             23
# Married-civ-spouse     14976          14340   14976      14976          14976
# Married-spouse-absent    418            389     418        418            418
# Never-married          10683           9917   10683      10683          10683
# Separated               1025            959    1025       1025           1025
# Widowed                  993            840     993        993            993
#
#                        occupation  relationship   race    sex  capital_gain  \
# marital_status
# Divorced                     4258          4443   4443   4443          4443
# Married-AF-spouse              21            23     23     23            23
# Married-civ-spouse          14339         14976  14976  14976         14976
# ...

# %%
values = df['marital_status'].value_counts().sort_index()
plt.gca().set_aspect("equal")
plt.pie(values)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-4b8e5d3d3eaf> in <module>()
# ----> 1 values = df['marital_status'].value_counts().sort_index()
#       2 plt.gca().set_aspect("equal")
#       3 plt.pie(values)
#       4 plt.show()
#
# NameError: name 'df' is not defined

# %%
values = df['marital_status'].value_counts().sort_values(ascending=True)

# %%
df.groupby('marital_status').count()
# Out:
#                          age  working_class  fmlgtw  education  education_num  \
# marital_status
# Divorced                4443           4259    4443       4443           4443
# Married-AF-spouse         23             21      23         23             23
# Married-civ-spouse     14976          14340   14976      14976          14976
# Married-spouse-absent    418            389     418        418            418
# Never-married          10683           9917   10683      10683          10683
# Separated               1025            959    1025       1025           1025
# Widowed                  993            840     993        993            993
#
#                        occupation  relationship   race    sex  capital_gain  \
# marital_status
# Divorced                     4258          4443   4443   4443          4443
# Married-AF-spouse              21            23     23     23            23
# Married-civ-spouse          14339         14976  14976  14976         14976
# ...

# %%
values
# Out:
# Married-AF-spouse           23
# Married-spouse-absent      418
# Widowed                    993
# Separated                 1025
# Divorced                  4443
# Never-married            10683
# Married-civ-spouse       14976
# Name: marital_status, dtype: int64

# %%
values.max()
# Out:
# 14976

# %%
 status=values.sort_values( ascending=False)

# %%
status
# Out:
# Married-civ-spouse       14976
# Never-married            10683
# Divorced                  4443
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital_status, dtype: int64

# %%
def most_prominent_marital_status(dataframe):
    
    values = income_data['marital_status'].value_counts().sort_values(ascending=False)

    status =values.index[0]
    num_people =values[0]
    # YOUR CODE HERE
    #raise NotImplementedError()
    return (status, num_people)

# %%
(status, num_people) = most_prominent_marital_status(income_data)
nose.tools.assert_not_equal(status, "")
nose.tools.assert_greater(num_people, 10000)

# %%
(status, num_people) = most_prominent_marital_status(income_data)

# %%
(status, num_people)
# Out:
# (' Married-civ-spouse', 14976)

# %%
values.idxmax()
# Out:
# 222

# %%
values = (income_data['age'])
plt.hist(values)
plt.show()

# %%
plot = income_data['age'].plot(x="Some Data",y="Other Data",kind="hist")
plot.set_xlabel("age")
plot.set_ylabel("count")
plt.show()

# %%
young, middle_aged, old = (len(income_data[ income_data.age <=30])
                           , len(income_data[(income_data.age >30) & (income_data.age <=60)]),
                           len(income_data[ income_data.age >60]))

# %%
young =len(income_data[ income_data.age <=30])

# %%
young

# %%
old=len(income_data[ income_data.age >60])

# %%
old

# %%
middle=len(income_data[(income_data.age >30) & (income_data.age <=60)])

# %%
middle

# %%
income_data["age"].count()

# %%
old+middle+young

# %%
young, middle_aged, old = (len(income_data[ income_data.age <=30])
                           , len(income_data[(income_data.age >30) & (income_data.age <=60)]),
                           len(income_data[ income_data.age >60]))

# %%
print (young, middle_aged, old)

# %%
country=df['native_country'].value_counts().sort_values(ascending=False)

# %%
country
# Out:
# United-States                 29170
# Mexico                          643
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# ...

# %%
country.index[1]
# Out:
# 'Mexico'

# %%
country.size
# Out:
# 41

# %%
country[1]
# Out:
# 198

# %%
df.groupby(['occupation'])['hours_per_week'].mean().sort_values(ascending=False)
# Out:
# occupation
# Farming-fishing      46.989940
# Exec-managerial      44.987703
# Transport-moving     44.656230
# Protective-serv      42.870570
# Prof-specialty       42.386715
# Craft-repair         42.304221
# Sales                40.781096
# Machine-op-inspct    40.755744
# Armed-Forces         40.666667
# Tech-support         39.432112
# Handlers-cleaners    37.947445
# Adm-clerical         37.558355
# Other-service        34.701669
# Priv-house-serv      32.885906
# Name: hours_per_week, dtype: float64

# %%
df.groupby(['occupation']).mean()
# Out:
#                          age         fmlgtw  education_num  capital_gain  \
# occupation
# Adm-clerical       36.964456  192043.396286      10.113528    495.954907
# Armed-Forces       30.222222  215425.888889      10.111111      0.000000
# Craft-repair       39.031471  192132.599658       9.110759    649.512808
# Exec-managerial    42.169208  184414.012543      11.449090   2262.772996
# Farming-fishing    41.211268  170190.176056       8.608652    589.726358
# Handlers-cleaners  32.165693  204391.006569       8.510219    257.572993
# Machine-op-inspct  37.715285  195040.877622       8.487512    328.689311
# Other-service      34.949621  188608.452200       8.779666    191.301669
# Priv-house-serv    41.724832  201107.523490       7.362416    279.852349
# Prof-specialty     40.517633  185296.613285      12.905072   2726.699517
# Protective-serv    38.953775  202039.953775      10.184900    708.098613
# Sales              37.353973  190885.892055      10.299726   1319.829315
# ...

# %%
  valuese= df['marital_status'].value_counts().sort_values(ascending=False)

# %%
df.applymap(lambda x: np.nan if x == '?' else x)
# Out:
#        age     working_class  fmlgtw     education  education_num  \
# 0       39         State-gov   77516     Bachelors             13
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 4       28           Private  338409     Bachelors             13
# 5       37           Private  284582       Masters             14
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 12      23           Private  122272     Bachelors             13
# ...

# %%
df.groupby(['occupation'])['hours_per_week'].mean()
# Out:
# occupation
# Adm-clerical         37.558355
# Armed-Forces         40.666667
# Craft-repair         42.304221
# Exec-managerial      44.987703
# Farming-fishing      46.989940
# Handlers-cleaners    37.947445
# Machine-op-inspct    40.755744
# Other-service        34.701669
# Priv-house-serv      32.885906
# Prof-specialty       42.386715
# Protective-serv      42.870570
# Sales                40.781096
# Tech-support         39.432112
# Transport-moving     44.656230
# Name: hours_per_week, dtype: float64

# %%
hey=df.groupby(['occupation'])['hours_per_week'].mean().sort_values(ascending=False)

# %%
hey
# Out:
# occupation
# Farming-fishing      46.989940
# Exec-managerial      44.987703
# Transport-moving     44.656230
# Protective-serv      42.870570
# Prof-specialty       42.386715
# Craft-repair         42.304221
# Sales                40.781096
# Machine-op-inspct    40.755744
# Armed-Forces         40.666667
# Tech-support         39.432112
# Handlers-cleaners    37.947445
# Adm-clerical         37.558355
# Other-service        34.701669
# Priv-house-serv      32.885906
# Name: hours_per_week, dtype: float64

# %%
plt.figure(figsize = (12,6))
plt.title("Weekly hours by occupation")
plt.barh(range(len(hey)), hey)
plt.yticks(list(range(len(hey))), hey.index)
plt.show()

# %%
hey.index[0]
# Out:
# 'Farming-fishing'

# %%
hey[0]
# Out:
# 46.989939637826964

# %%
def get_mean_working_hours_by_income(dataframe):
    # YOUR CODE HERE
        hours = dataframe.groupby(['occupation'])['hours_per_week'].mean().sort_values(ascending=False) 
        return hours

# %%
hours = get_mean_working_hours_by_income(income_data)
print(hours)
nose.tools.assert_almost_equal(hours["Handlers-cleaners"], 37.95, delta = 0.01)
# Out:
# occupation
# Farming-fishing      46.989940
# Exec-managerial      44.987703
# Transport-moving     44.656230
# Protective-serv      42.870570
# Prof-specialty       42.386715
# Craft-repair         42.304221
# Sales                40.781096
# Machine-op-inspct    40.755744
# Armed-Forces         40.666667
# Tech-support         39.432112
# Handlers-cleaners    37.947445
# Adm-clerical         37.558355
# Other-service        34.701669
# Priv-house-serv      32.885906
# Name: hours_per_week, dtype: float64

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-ae64e1e6c769> in <module>()
# ----> 1 hours = dataframe.groupby(['occupation'])['hours_per_week'].mean().sort_values(ascending=False)
#
# NameError: name 'dataframe' is not defined

# %%
def get_mean_working_hours_by_income(dataframe):
    # YOUR CODE HERE
    return dataframe.groupby(['occupation'])['hours_per_week'].mean().sort_values(ascending=False)
